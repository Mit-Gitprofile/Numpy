# %%
# %pip install numpy

# %%
import numpy as np

class Indexing_Slicing:            
    def IndexingSlicing(self):
        while True:
            print("\n Chose An option:-")
            print("  1. Indexing  2. Slicing  3. Go back")
            indexchoice=int(input("Enter Your Choise:"))
            if indexchoice==1:        #indexind for 1d 2d or 3d array
                if arr.ndim==1:
                    Index=int(input("Enter Index To catch value from 1D array:"))
                    print(f"Arry[{Index}] : {arr[Index]}")
                elif arr.ndim==2:
                    row,col=map(int,input("Enter Index To catch value from 2D array (row,col):").split(","))
                    print(f"Arry[{row},{col}] : {arr[row,col]}")
                elif arr.ndim==3:
                    row,col,dep=map(int,input("Enter Index To catch value from 3D array (row,col,dep):").split(","))
                    print(f"Arry[{row},{col},{dep}] : \n{arr[row,col,dep]}")
                
            elif indexchoice==2:        #slicing for 1d 2d or 3d array
                if arr.ndim==1:
                    start,end=map(int,input("Enter slicing point for 1D array (Start:End):").split(":"))
                    print(f"\nSliced Array:\n{arr[start:end]}")
                elif arr.ndim==2:
                    rstart,rend=map(int,input("Enter the row range (Start:End):").split(":"))
                    cstart,cend=map(int,input("Enter the column range(Start:End):").split(":"))
                    print(f"\nSliced Array:\n{arr[rstart:rend,cstart:cend]}")
                elif arr.ndim==3:
                    r_start,r_end=map(int,input("Enter the row range (Start:End):").split(":"))
                    c_start,c_end=map(int,input("Enter the column range(Start:End):").split(":"))
                    d_start,d_end=map(int,input("Enter the depth range(Start:End):").split(":"))
                    print(f"\nSliced Array:\n{arr[r_start:r_end,c_start:c_end,d_start:d_end]}")
            elif indexchoice==3:    
                break
    
class MathematicalOperation:
    def Addition(self):
        while True:
            total_ele=np.prod(arr.shape)
            arr2=np.array(input(f"Enter {total_ele} elements for addition (space separated):").split(),dtype=int)
            if len(arr2)==total_ele:
                newarr=arr2.reshape(arr.shape)          #shape new array according default array
                result=arr + newarr
                print("Original array :\n",arr)
                print("Result of Addition:\n",result)
                break
            else:
                print(f"Enter Only {total_ele} elements...")
        

    def Subtraction(self):                         # Subtraction of Array1 +Array2
        while True:
            total_ele=np.prod(arr.shape)
            arr2=np.array(input(f"Enter {total_ele} elements for Subtraction (space separated):").split(),dtype=int)
            if len(arr2)==total_ele:
                newarr=arr2.reshape(arr.shape)
                result=arr - newarr
                print("Original array :\n",arr)
                print("Result of Subtraction:\n",result)
                break
            else:
                print(f"Enter Only {len(arr)} elements...")

    def Multiplication(self):                         # Multiplication of Array1 +Array2
        while True:
            total_ele=np.prod(arr.shape)
            arr2=np.array(input(f"Enter {total_ele} elements for Multiplication (space separated):").split(),dtype=int)
            if len(arr2)==total_ele:
                newarr=arr2.reshape(arr.shape)
                result=arr * newarr
                print("Original array :\n",arr)
                print("Result of Multiplication:\n",result)
                break
            else:
                print(f"Enter Only {len(arr)} elements...")

    def Division(self):                         # Division of Array1 +Array2
        while True:
            total_ele=np.prod(arr.shape)
            arr2=np.array(input(f"Enter {total_ele} elements for Division (space separated):").split(),dtype=int)
            if len(arr2)==total_ele:
                newarr=arr2.reshape(arr.shape)
                result=arr / newarr
                print("Original array :\n",arr)
                print("Result of Division:\n",result)
                break
            else:
                print(f"Enter Only {len(arr)} elements...")
        
        
class Combine_Split:
    def Combine(self): 
        total_ele=np.prod(arr.shape)    
        while True:#find all elements length using prod function
            arr2=np.array(input(f"Enter {total_ele} elements for combine (space separated):").split(),dtype=int)
            if len(arr)==len(arr2):
                newarr=arr2.reshape(arr.shape)
                if arr.ndim==1:
                    result=np.concatenate((arr,newarr))
                elif arr.ndim==2:
                    result=np.concatenate((arr,newarr),axis=1)
                elif arr.ndim==3:
                    result=np.concatenate((arr,newarr),axis=0)
                else:
                    print("Invelid dimention")
                print("Combined array:\n",result)
                break
            else:
                print(f"Enter Only {total_ele} elements...")
        
    def Split(self):   #split array
        print(f"Original array:\n",arr)
        if arr.ndim==1:
            split_array=np.array_split(arr,2)       #split 1d array
        elif arr.ndim==2:
            split_array=np.hsplit(arr,2)        #split 2d array horizontal
            print("Array Splited row-wise.")
        elif arr.ndim==3:   
            split_array=np.dsplit(arr,3)        #split 3d array depthwise
            print("Array Splited depth-wise.")
        else:
            print("Invelid dimention")
        print("Splitted array:")
        for i in split_array:
            print(i)
            
class SearchSortFilter:
    
    def Search(self):                       #Search Value from array
        print("Original array:\n",arr)
        value=int(input("Enter value for searching:"))
        result=np.where(arr==value)
        if result!=0:
            print(f"Value {value} found at : {result}")
        else:
            print(f"Value {value} not found in the array.")

    def Sort(self):                       #Sort array
        sorted_array=np.sort(arr)
        print(f"Sorted Array:\n",sorted_array)
        print("Sorting applied row-wise.")
            
    def Filter(self):                       #Filter array
        filtered_array=arr[arr%2==0]
        print("All even value Filter from Array:\n",filtered_array)

class Agregate_Statistics:
    def Sum(self):                                  #Sum
        print("Original Array:\n",arr)
        print("\nSum : ",np.sum(arr))
    def Mean(self):                                 #Mean
        print("Original Array:\n",arr)
        print("\nMean : ",np.mean(arr))
    def Median(self):                               #Median
        print("Original Array:\n",arr)
        print("\nMedian : ",np.median(arr))
    def StandardDevision(self):                     #Standard Devision
        print("Original Array:\n",arr)
        print("\nStandard Devision : ",np.std(arr))
    def Varience(self):                             #Varience
        print("Original Array:\n",arr)
        print("\nVarience : ",np.var(arr))
    

obj = Indexing_Slicing()            #objects
mth = MathematicalOperation()
cmb = Combine_Split()
fil = SearchSortFilter()
agr = Agregate_Statistics()
print("\n=========================")
print(" Welcome To Numpy Analyzer")
print("==========================") 
while True:     #LOOP CONTINUE WHILE TRUE
    print("===============================================")
    print("  ***   Choose an option:")
    print("-----------------------------------------------")
    print("   1. Create A Numpy Array")
    print("   2. Perform Mathematical Operations")                        #OPTIONS
    print("   3. Combine Or Split Arrays")
    print("   4. Search , Sort Or Filter Arrays")
    print("   5. Compute Aggregate and Statistics")
    print("   6. Exit")
    print("===============================================\n")

    main_choice=int(input("Enter your choice:"))

    match main_choice:      #SWITCH CASE FOR MATCH CHOICES
    
    #CASE 1 ARRAY CREATION WITH INDEXING & SLICING
        case 1:
            while True:
                print("\n==============================================")
                print("  ***   Select the type of array to create:")
                print("   1. 1D Array")
                print("   2. 2D Array")
                print("   3. 3D Array")
                print("   4. Go back")

                array_choice=int(input("Enter Your Choice:"))
                match array_choice:
                    case 1:                                                      #1D array
                        length=int(input("Enter the length for 1D array: "))
                        while True:
                            arr=np.array((input(f"Enter {length} Elements for 1D Array (Space separated):").split()),dtype=int)
                            if len(arr)==length:
                                print("1D Array created Successfully:\n",arr)
                                obj.IndexingSlicing()
                                break
                            else:
                                print(f"Please enter only {length} elements...")
                                
                    case 2:                                                      #2D array
                        row=int(input("Enter the number of rows: "))
                        col=int(input("Enter the number of columns: "))
                        while True:
                            elements=np.array(input(f"Enter {row*col} Elements for 2D Array (Space separated):").split(),dtype=int)
                            if len(elements)==(row*col):
                                arr=elements.reshape(row,col)
                                print("2D Array created Successfully:\n",arr)
                                obj.IndexingSlicing()
                                break
                            else:
                                print(f"Please enter only {row*col} elements...")
                                
                    case 3:                                                      #3D array
                        row=int(input("Enter the number of rows: "))
                        col=int(input("Enter the number of columns: "))
                        depth=int(input("Enter the number of depth: "))
                        while True:
                            elements=np.array(input(f"Enter {row*col*depth} Elements for 3D Array (Space separated):").split(),dtype=int)
                            if len(elements)==(row*col*depth):
                                arr=elements.reshape(row,col,depth)
                                print("3D Array created Successfully:\n",arr)
                                obj.IndexingSlicing()
                                break
                            else:
                                print(f"Please enter only {row*col*depth} elements...")
                                
                    case 4:
                        break
    #CASE 2 MATHEMATICAL OPERATIONS                     
        case 2:
            print("\n==============================================")
            print("  ***   Select the mathematical operation:")
            print("==============================================")
            print(" 1. Addition  2. Subtraction  3. Multiplication  4. Division")

            choice=int(input("Enter your choice:"))
            if choice==1:
                mth.Addition()          #call methods
            elif choice==2:
                mth.Subtraction()
            elif choice==3:
                mth.Multiplication()
            elif choice==4:
                mth.Division()
            else:
                print("Invalid choice...")
                
    #CASE 3 COMBINE OR SPLIT ARRAYS                 
        case 3:
            print("\n==============================================")
            print("  ***   Choose an operation:")
            print("==============================================")
            print(" 1. Combine arrays  2. Split arrays")

            choice=int(input("Enter your choice:"))
            if choice==1:
                cmb.Combine()          #call methods
            elif choice==2:
                cmb.Split()
            else:
                print("Invalid choice...")

    #CASE 4 SEARCH , SORT AND FILTER OPERATIONS                 
        case 4:
            print("\n==============================================")
            print("  ***   Choose an operation:")
            print("==============================================")
            print(" 1. Search  2. Sort  3. Filter")

            choice=int(input("Enter your choice:"))
            if choice==1:
                fil.Search()          #call methods
            elif choice==2:
                fil.Sort()
            elif choice==3:
                fil.Filter()
            else:
                print("Invalid choice...")

    #CASE 5 BESIC ADDITIONAL OPERATIONS                  
        case 5:
            print("\n==============================================")
            print("  *** Choose an aggregate/statistical operations:")
            print("==============================================")
            print(" 1.Sum  2.Mean  3.Median  4.Standard Devision  5.Varience")

            choice=int(input("Enter your choice:"))
            if choice==1:
                agr.Sum()          #call methods
            elif choice==2:
                agr.Mean()
            elif choice==3:
                agr.Median()
            elif choice==4:
                agr.StandardDevision()
            elif choice==5:
                agr.Varience()
            else:
                print("Invalid choice...")
                        
    #CASE 6 FOR BREAK
        case 6:
            print("Exiting program...")
            break
